# %% [markdown]
# # Python

# %% [markdown]
# .ipynb - integrated python notebook

# %% [raw]
# Program - set of instructiones for computers define for programming specific task.

# %% [raw]
# programming - art of writting those instructiones ---- (syntax  +  content)

# %% [raw]
# coding -  how to write instructiones(syntax+Content)

# %% [raw]
# ---language - medium of communicationes
#
# a)human language
#
# 1.hindi
# 2.marathi
# 3.english
#
# b)system program language
#
# Computer language(low level binary)
#
# 1.binary language(0/1)
# 2.high level language('a','A','+','1','2','@','?')
# ex. c,c++,java,python.

# %% [raw]
# Types of translator :----
#
# 1.Interpreter - line by line code executed or run (Python)
# 2.compiler - complete program run at a time (c,c++,java).

# %% [raw]
# print('welcome to the' # () - parenthesis(Round bracket), print - function

# %%
print ('welcome to the data sciecne classes')
# Out:
# welcome to the data sciecne classes

# %%
print('welcome to the data science class')
# Out:
# welcome to the data science class

# %%
print('welcome to the python workshop')
# Out:
# welcome to the python workshop

# %% [raw]
# # shortcuts
#
# ctrl + enter  = run the cell and stay in the same cell.
# shift + enter = run the same cell and move to the next cell and if the cell is not there  it will create a new one.
# alt+ enter    = run the cell and move to the same cell next line.

# %%
print('welcome to the data science class') # proper  syntax
# Out:
# welcome to the data science class

# %% [markdown]
# ## COMMENT

# %%
# -  single line comment 
# ctrl + / - multi line  comment

# %% [markdown]
# ### Python

# %%
- Birth date - 20 feb ,1991
- official use(develop) - 1989
- Developed by Guido Van Rossam
- It is Recommeded Language for Begineers.

# %% [raw]
# # - Features Of Python:(imp)
#
# 1. simple and easy to learn
# 2. high level programming language
# 3. freeware and open source
# 4. Interpreted(code executed line by line)
#    Q.# compiler
# 5. Dynamically Typed(there is no need to declare any variable.)
# question -
#    Q. # statiscally typed( not flexible ac to languages)
# 6. extensive libraries.
# 7. platform Independent.
# 8. procedural and object oriented programming
